# %%
import pandas as pd

# %%
animals=['Tiger','Bear','Moose']
s=pd.Series(animals)
s
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.name='Animals'
s.name
# Out:
# 'Animals'

# %%
s
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# Name: Animals, dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals=['Tiger','Bear',None]
s=pd.Series(animals)
s
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers=[1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np

# %%
None,np.nan
# Out:
# (None, nan)

# %%
sports={'archery':'bhutan','golf':'scotland','taekwodo':'south kotea'}
s=pd.Series(sports)
s
# Out:
# archery          bhutan
# golf           scotland
# taekwodo    south kotea
# dtype: object

# %%
s.index
# Out:
# Index(['archery', 'golf', 'taekwodo'], dtype='object')

# %%
s=pd.Series(['tiger','bear','moose'],index=['india','america','canada'])
s
# Out:
# india      tiger
# america     bear
# canada     moose
# dtype: object

# %% [markdown]
# # Querying a series

# %%
sports={'archery':'bhutan','golf':'scotland','sumo':'japan','taekwodo':'south korea'}
s=pd.Series(sports)
s
# Out:
# archery          bhutan
# golf           scotland
# sumo              japan
# taekwodo    south korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'south korea'

# %%
s.loc['sumo']
# Out:
# 'japan'

# %%
s[0]
# Out:
# 'bhutan'

# %%
s['golf']
# Out:
# 'scotland'

# %%
sports={99:'bhutan',100:'scotland',101:'japan',102:'south korea'}
s=pd.Series(sports)
s
# Out:
# 99          bhutan
# 100       scotland
# 101          japan
# 102    south korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'south korea'

# %%
s.loc[99]
# Out:
# 'bhutan'

# %%
s[99]
# Out:
# 'bhutan'

# %%
s=pd.Series([100.00,120.00,101.00,3.00])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
for i in s:
    print(i)
# Out:
# 100.0
# 120.0
# 101.0
# 3.0

# %%
total=0
for item in s:
    total+=item
print(total)
# Out:
# 324.0

# %%
import numpy as np
total=np.sum(s)
print(total)
# Out:
# 324.0

# %%
s=pd.Series(np.random.randint(0,1000,10000))
s.head()
# Out:
# 0    920
# 1    860
# 2    168
# 3    673
# 4    848
# dtype: int32

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 5  #magical function in jupyter notebook
summary=0
for item in s:
    summary+=item
# Out:
# 1.34 ms ± 17.5 µs per loop (mean ± std. dev. of 7 runs, 5 loops each)

# %%
# %%time -n 5
summary = np.sum(s)
# Out:
# UsageError: Can't use statement directly after '%%time'!

# %%
s+=2
s.head()
# Out:
# 0    922
# 1    862
# 2    170
# 3    675
# 4    850
# dtype: int32

# %%
for label, value in s.iteritems():
    s.set_value(label,value+2)
s.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 0    924
# 1    864
# 2    172
# 3    677
# 4    852
# dtype: int32

# %%
s.set_value(0,997)
s.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
# 0    997
# 1    864
# 2    172
# 3    677
# 4    852
# dtype: int32

# %%
import pandas as pd
# %%timeit -n 1
s=pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]=value+2
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
# %%timeit -n 1
s=pd.Series(np.random.randint(0,1000,10000))
*s+=2
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-36-0ead734b963e>", line 1, in <module>
#     get_ipython().run_cell_magic('timeit', '-n 1', 's=pd.Series(np.random.randint(0,1000,10000))\n*s+=2\n')
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2352, in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File "<C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-61>", line 2, in timeit
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py", line 1093, in timeit
#     ast_stmt = self.shell.compile.ast_parse(transform(cell))
#
# ...

# %%
original_sports=pd.Series({'archery':'bhutan','golf':'scotland','sumo':'japan','taekwodo':'south korea'})
cricket_countries=pd.Series(['australia','india','pakistan','england'],index=['cricket','cricket','cricket','cricket',])
all_countries=original_sports.append(cricket_countries)

# %%
all_countries
# Out:
# archery          bhutan
# golf           scotland
# sumo              japan
# taekwodo    south korea
# cricket       australia
# cricket           india
# cricket        pakistan
# cricket         england
# dtype: object

# %%
original_sports
# Out:
# archery          bhutan
# golf           scotland
# sumo              japan
# taekwodo    south korea
# dtype: object

# %%
cricket_countries
# Out:
# cricket    australia
# cricket        india
# cricket     pakistan
# cricket      england
# dtype: object

# %%
all_countries.loc['cricket']).replace({'australia':'Australia'}
# Out:
#   File "<ipython-input-41-fc9c44bb8816>", line 1
#     all_countries.loc['cricket']).replace({'australia':'Australia'}
#                                 ^
# SyntaxError: invalid syntax

# %%
all_countries[4]='Australia'
all_countries
# Out:
# archery          bhutan
# golf           scotland
# sumo              japan
# taekwodo    south korea
# cricket       Australia
# cricket           india
# cricket        pakistan
# cricket         england
# dtype: object

# %% [markdown]
# # DataFrame

# %%
purchase_1=pd.Series({'name':'chris','item purchased':'dog food','cost':22.50})
purchase_2=pd.Series({'name':'kevyn','item purchased':'kitty litter','cost':2.50})
purchase_3=pd.Series({'name':'vinod','item purchased':'bird seed','cost':5.00})
df=pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['store 1','store 1','store 2',])
df.head()
# Out:
#           name item purchased  cost
# store 1  chris       dog food  22.5
# store 1  kevyn   kitty litter   2.5
# store 2  vinod      bird seed   5.0

# %%
df.loc['store 2']
# Out:
# name                  vinod
# item purchased    bird seed
# cost                      5
# Name: store 2, dtype: object

# %%
type(df.loc['store 2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['store 1']
# Out:
#           name item purchased  cost
# store 1  chris       dog food  22.5
# store 1  kevyn   kitty litter   2.5

# %%
df.loc['store 1','cost']
# Out:
# store 1    22.5
# store 1     2.5
# Name: cost, dtype: float64

# %%
df.T
# Out:
#                  store 1       store 1    store 2
# name               chris         kevyn      vinod
# item purchased  dog food  kitty litter  bird seed
# cost                22.5           2.5          5

# %%
df.T.loc['item purchased']
# Out:
# store 1        dog food
# store 1    kitty litter
# store 2       bird seed
# Name: item purchased, dtype: object

# %%
df['item purchased']
# Out:
# store 1        dog food
# store 1    kitty litter
# store 2       bird seed
# Name: item purchased, dtype: object

# %%
df
# Out:
#           name item purchased  cost
# store 1  chris       dog food  22.5
# store 1  kevyn   kitty litter   2.5
# store 2  vinod      bird seed   5.0

# %%
df.loc['store 1']['cost']
# Out:
# store 1    22.5
# store 1     2.5
# Name: cost, dtype: float64

# %%
df.loc[:,['Name', 'cost']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#          Name  cost
# store 1   NaN  22.5
# store 1   NaN   2.5
# store 2   NaN   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('store 1')
copy_df
# Out:
#           name item purchased  cost
# store 2  vinod      bird seed   5.0

# %%
copy_df=df.copy()
copy_df.drop('store 1',inplace=True)
copy_df
# Out:
#           name item purchased  cost
# store 2  vinod      bird seed   5.0

# %%
del copy_df['name']
copy_df
# Out:
#         item purchased  cost
# store 2      bird seed   5.0

# %%
df['location']=None
df
# Out:
#           name item purchased  cost location
# store 1  chris       dog food  22.5     None
# store 1  kevyn   kitty litter   2.5     None
# store 2  vinod      bird seed   5.0     None

# %%
df.loc['store 2','state']='mumbai'
df
# Out:
#           name item purchased  cost location   state
# store 1  chris       dog food  22.5     None     NaN
# store 1  kevyn   kitty litter   2.5     None     NaN
# store 2  vinod      bird seed   5.0     None  mumbai

# %%
df['state']['store 2']='Mumbai'
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           name item purchased  cost location   state
# store 1  chris       dog food  22.5     None     NaN
# store 1  kevyn   kitty litter   2.5     None     NaN
# store 2  vinod      bird seed   5.0     None  Mumbai

# %% [markdown]
# # DataFrame indexing and loading

# %%
df
# Out:
#           name item purchased  cost location   state
# store 1  chris       dog food  22.5     None     NaN
# store 1  kevyn   kitty litter   2.5     None     NaN
# store 2  vinod      bird seed   5.0     None  Mumbai

# %%
costs=df['cost']
costs
# Out:
# store 1    22.5
# store 1     2.5
# store 2     5.0
# Name: cost, dtype: float64

# %%
costs+=1
costs
# Out:
# store 1    23.5
# store 1     3.5
# store 2     6.0
# Name: cost, dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns[0]
# Out:
# '№ Summer'

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['Gold']
# Out:
# Afghanistan (AFG)                                  0
# Algeria (ALG)                                      5
# Argentina (ARG)                                   18
# Armenia (ARM)                                      1
# Australasia (ANZ) [ANZ]                            3
# Australia (AUS) [AUS] [Z]                        139
# Austria (AUT)                                     18
# Azerbaijan (AZE)                                   6
# Bahamas (BAH)                                      5
# Bahrain (BRN)                                      0
# Barbados (BAR) [BAR]                               0
# Belarus (BLR)                                     12
# Belgium (BEL)                                     37
# Bermuda (BER)                                      0
# Bohemia (BOH) [BOH] [Z]                            0
# Botswana (BOT)                                     0
# Brazil (BRA)                                      23
# British West Indies (BWI) [BWI]                    0
# ...

# %% [markdown]
# ## find the countries names who got more or equal  5 gold madels

# %%
df['Gold.2']>=5
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                   False
# Australasia (ANZ) [ANZ]                         False
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %% [markdown]
# ### 1-how many countries won 1 gold medal in summer?

# %%
len(df['Gold']>=1)
# Out:
# 147

# %%
len(df['Gold.2']>=1)
# Out:
# 147

# %%
only_gold=df.where(df['Gold']>0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
only_gold=only_gold.dropna()
only_gold.head()
# Out:
#                            # Summer   Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                  12.0    5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)                23.0   18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                   5.0    1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]         2.0    3.0     4.0     5.0   12.0       0.0
# Australia (AUS) [AUS] [Z]      25.0  139.0   152.0   177.0  468.0      18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0     15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0     41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0     11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0      2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0     43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
only_gold=df[df['Gold']>0]
only_gold.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %% [markdown]
# ### find the count of countries who got arleast 1 sliver medals in either summer or winter?

# %%
df[df['Silver.2']>=1]['Silver.2'].count()
# Out:
# 126

# %%
len(df[(df['Gold']>0)|(df['Gold.1']>0)])
# Out:
# 101

# %% [markdown]
# ### find countries which got at least one gold medal in winter and not in summer

# %%
df[(df['Gold.1']>0)&(df['Gold']==0)]
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %%
df['country'] =df.index
df.set_index('Gold').head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# ...

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df=df.reset_index()
df.head()
# Out:
#                      index  # Summer  Gold  Silver  Bronze  Total  # Winter  \
# 0        Afghanistan (AFG)        13     0       0       2      2         0
# 1            Algeria (ALG)        12     5       2       8     15         3
# 2          Argentina (ARG)        23    18      24      28     70        18
# 3            Armenia (ARM)         5     1       2       9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#    Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# 0       0         0         0        0       13       0         0         2
# 1       0         0         0        0       15       5         2         8
# 2       0         0         0        0       41      18        24        28
# 3       0         0         0        0       11       1         2         9
# 4       0         0         0        0        2       3         4         5
#
#    Combined total                  country
# ...

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df=df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df[['SUMLEV','STATE','COUNTY']]
# Out:
#       SUMLEV  STATE  COUNTY
# 1         50      1       1
# 2         50      1       3
# 3         50      1       5
# 4         50      1       7
# 5         50      1       9
# 6         50      1      11
# 7         50      1      13
# 8         50      1      15
# 9         50      1      17
# 10        50      1      19
# 11        50      1      21
# 12        50      1      23
# 13        50      1      25
# 14        50      1      27
# 15        50      1      29
# 16        50      1      31
# 17        50      1      33
# 18        50      1      35
# 19        50      1      37
# 20        50      1      39
# 21        50      1      41
# 22        50      1      43
# 23        50      1      45
# 24        50      1      47
# 25        50      1      49
# 26        50      1      51
# 27        50      1      53
# 28        50      1      55
# 29        50      1      57
# 30        50      1      59
# ...      ...    ...     ...
# 3162      50     55     129
# ...

# %%
columns_to_keep=[[]]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df=df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Alabama             40       3         6      1       0
#         Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama               4779736            4780127          4785161
#         Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
df
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Alabama                 40       3         6      1       0
#           Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
# ...

# %%
df.loc['Alabama','Autauga County']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                           ...
# Alabama Autauga County            55253            55175  ...
#
#                         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME  CTYNAME
# Alabama Autauga County          7.242091         -2.915927         -3.012349
#
#                         RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# STNAME  CTYNAME
# ...

# %%
df.loc[('Michigan','Washington County'),]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Michigan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-3cc09779aeb0> in <module>
# ----> 1 df.loc[('Michigan','Washington County')]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %% [markdown]
# # Missing  values

# %%
df=pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df.fillna?

# %%
df=df.set_index('time')
df.head()
# Out:
#               user       video  playback position paused  volume
# time
# 1469974424  cheryl  intro.html                  5  False    10.0
# 1469974454  cheryl  intro.html                  6    NaN     NaN
# 1469974544  cheryl  intro.html                  9    NaN     NaN
# 1469974574  cheryl  intro.html                 10    NaN     NaN
# 1469977514     bob  intro.html                  1    NaN     NaN

# %%
df=df.sort_index()
df.head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df=df.reset_index()
df=df.set_index(['time','user'])
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df.fillna(method='ffill').head()  # farword fill (previous values fill in next row)
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
df.fillna(method='bfill')   # backword fill (it will fill the valuse down to up)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6   True     5.0
#            sue     advanced.html                 24   True     5.0
# 1469974484 cheryl     intro.html                  7   True     5.0
# 1469974514 cheryl     intro.html                  8   True     5.0
# 1469974524 sue     advanced.html                 25   True     5.0
# 1469974544 cheryl     intro.html                  9   True     5.0
# 1469974554 sue     advanced.html                 26   True     5.0
# 1469974574 cheryl     intro.html                 10   True     5.0
# 1469974604 cheryl     intro.html                 11   True     5.0
# 1469974624 sue     advanced.html                 27   True     5.0
# 1469974634 cheryl     intro.html                 12   True     5.0
# ...
